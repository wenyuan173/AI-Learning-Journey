# %%
import pandas as pd

# %%
s1=pd.Series({"a":1,"b":2,"c":3})
print(s1*10)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# series对象的计算

# %%
s2=pd.Series([1,1,1,1])
s3=pd.Series([2,2,2,2],index=['a','b','c','d'])
s4=pd.Series([2,2,2,2],index=[1,2,3,4])

print(s2+s3)
print(s4+s2)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# dtype: float64
# 0    NaN
# 1    3.0
# 2    3.0
# 3    3.0
# 4    NaN
# dtype: float64
