# %%
import pandas as pd
import os

df = pd.DataFrame({"age":[20,30,40,50],"name":["tom","alen","alex","emma"],"id":[101,102,103,104]})

df.set_index("id",inplace=True)

df
# Out:
#      age  name
# id
# 101   20   tom
# 102   30  alen
# 103   40  alex
# 104   50  emma

# %%
os.makedirs("data",exist_ok=True)
df.to_csv("data/p1_df.csv")

# %%
df.to_csv("data/p1_df2.csv",index=False)#不保存索引

# %%
df_csv=pd.read_csv("data/p1_df.csv",index_col="id")
print(df_csv)
# Out:
#      age  name
# id
# 101   20   tom
# 102   30  alen
# 103   40  alex
# 104   50  emma

# %%
df2_csv=pd.read_csv("data/p1_df2.csv")
print(df2_csv)
# Out:
#    age  name
# 0   20   tom
# 1   30  alen
# 2   40  alex
# 3   50  emma
